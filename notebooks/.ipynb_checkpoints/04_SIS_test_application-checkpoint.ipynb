# %% [markdown]
# ## Test Flask App
# From the other notebook, `03_SIS_run_application.ipynb`, the flask app is running and ready to serve requests using python http or `curl` statements.

# %% [markdown]
# We can start by testing that the server is indeed running:

# %%
# !curl http://localhost:5000/status
# Out:
# {
#   "status": "ok"
# }

# %% [markdown]
# Now we can use curl to send the name of an image, and wait for the result:

# %%
# !curl -X POST -H "Content-Type: application/json" --data '{"data": "test_sample_256_10.jpg"}' http://localhost:5000/predictions
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN"
#   "http://www.w3.org/TR/html4/loose.dtd">
# <html>
#   <head>
#     <title>cv2.error: OpenCV(4.5.5) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function &#x27;cvtColor&#x27; // Werkzeug Debugger</title>
#     <link rel="stylesheet" href="?__debugger__=yes&amp;cmd=resource&amp;f=style.css"
#         type="text/css">
#     <!-- We need to make sure this has a favicon so that the debugger does
#          not accidentally trigger a request to /favicon.ico which might
#          change the application's state. -->
#     <link rel="shortcut icon"
#         href="?__debugger__=yes&amp;cmd=resource&amp;f=console.png">
#     <script src="?__debugger__=yes&amp;cmd=resource&amp;f=debugger.js"></script>
#     <script type="text/javascript">
#       var TRACEBACK = 140249946318400,
#           CONSOLE_MODE = false,
#           EVALEX = true,
#           EVALEX_TRUSTED = false,
#           SECRET = "RzMtOgsuloYixmIhasAA";
#     </script>
#   </head>
#   <body style="background-color: #fff">
#     <div class="debugger">
# <h1>cv2.error</h1>
# <div class="detail">
#   <p class="errormsg">cv2.error: OpenCV(4.5.5) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function &#x27;cvtColor&#x27;</p>
# </div>
# <h2 class="traceback">Traceback <em>(most recent call last)</em></h2>
# <div class="traceback">
#   <h3></h3>
#   <ul><li><div class="frame" id="frame-140249946327936">
#   <h4>File <cite class="filename">"/opt/app-root/lib/python3.8/site-packages/flask/app.py"</cite>,
#       line <em class="line">2091</em>,
#       in <code class="function">__call__</code></h4>
#   <div class="source "><pre class="line before"><span class="ws">    </span>def __call__(self, environ: dict, start_response: t.Callable) -&gt; t.Any:</pre>
# <pre class="line before"><span class="ws">        </span>&quot;&quot;&quot;The WSGI server calls the Flask application object as the</pre>
# <pre class="line before"><span class="ws">        </span>WSGI application. This calls :meth:`wsgi_app`, which can be</pre>
# <pre class="line before"><span class="ws">        </span>wrapped to apply middleware.</pre>
# <pre class="line before"><span class="ws">        </span>&quot;&quot;&quot;</pre>
# <pre class="line current"><span class="ws">        </span>return self.wsgi_app(environ, start_response)</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140249946325728">
#   <h4>File <cite class="filename">"/opt/app-root/lib/python3.8/site-packages/flask/app.py"</cite>,
#       line <em class="line">2076</em>,
#       in <code class="function">wsgi_app</code></h4>
#   <div class="source "><pre class="line before"><span class="ws">            </span>try:</pre>
# <pre class="line before"><span class="ws">                </span>ctx.push()</pre>
# <pre class="line before"><span class="ws">                </span>response = self.full_dispatch_request()</pre>
# <pre class="line before"><span class="ws">            </span>except Exception as e:</pre>
# <pre class="line before"><span class="ws">                </span>error = e</pre>
# <pre class="line current"><span class="ws">                </span>response = self.handle_exception(e)</pre>
# <pre class="line after"><span class="ws">            </span>except:  # noqa: B001</pre>
# <pre class="line after"><span class="ws">                </span>error = sys.exc_info()[1]</pre>
# <pre class="line after"><span class="ws">                </span>raise</pre>
# <pre class="line after"><span class="ws">            </span>return response(environ, start_response)</pre>
# <pre class="line after"><span class="ws">        </span>finally:</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140249946327264">
#   <h4>File <cite class="filename">"/opt/app-root/lib/python3.8/site-packages/flask/app.py"</cite>,
#       line <em class="line">2073</em>,
#       in <code class="function">wsgi_app</code></h4>
#   <div class="source "><pre class="line before"><span class="ws">        </span>ctx = self.request_context(environ)</pre>
# <pre class="line before"><span class="ws">        </span>error: t.Optional[BaseException] = None</pre>
# <pre class="line before"><span class="ws">        </span>try:</pre>
# <pre class="line before"><span class="ws">            </span>try:</pre>
# <pre class="line before"><span class="ws">                </span>ctx.push()</pre>
# <pre class="line current"><span class="ws">                </span>response = self.full_dispatch_request()</pre>
# <pre class="line after"><span class="ws">            </span>except Exception as e:</pre>
# <pre class="line after"><span class="ws">                </span>error = e</pre>
# <pre class="line after"><span class="ws">                </span>response = self.handle_exception(e)</pre>
# <pre class="line after"><span class="ws">            </span>except:  # noqa: B001</pre>
# <pre class="line after"><span class="ws">                </span>error = sys.exc_info()[1]</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140249946325296">
#   <h4>File <cite class="filename">"/opt/app-root/lib/python3.8/site-packages/flask/app.py"</cite>,
#       line <em class="line">1518</em>,
#       in <code class="function">full_dispatch_request</code></h4>
#   <div class="source "><pre class="line before"><span class="ws">            </span>request_started.send(self)</pre>
# <pre class="line before"><span class="ws">            </span>rv = self.preprocess_request()</pre>
# <pre class="line before"><span class="ws">            </span>if rv is None:</pre>
# <pre class="line before"><span class="ws">                </span>rv = self.dispatch_request()</pre>
# <pre class="line before"><span class="ws">        </span>except Exception as e:</pre>
# <pre class="line current"><span class="ws">            </span>rv = self.handle_user_exception(e)</pre>
# <pre class="line after"><span class="ws">        </span>return self.finalize_request(rv)</pre>
# <pre class="line after"><span class="ws"></span> </pre>
# <pre class="line after"><span class="ws">    </span>def finalize_request(</pre>
# <pre class="line after"><span class="ws">        </span>self,</pre>
# <pre class="line after"><span class="ws">        </span>rv: t.Union[ResponseReturnValue, HTTPException],</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140249946325056">
#   <h4>File <cite class="filename">"/opt/app-root/lib/python3.8/site-packages/flask/app.py"</cite>,
#       line <em class="line">1516</em>,
#       in <code class="function">full_dispatch_request</code></h4>
#   <div class="source "><pre class="line before"><span class="ws">        </span>self.try_trigger_before_first_request_functions()</pre>
# <pre class="line before"><span class="ws">        </span>try:</pre>
# <pre class="line before"><span class="ws">            </span>request_started.send(self)</pre>
# <pre class="line before"><span class="ws">            </span>rv = self.preprocess_request()</pre>
# <pre class="line before"><span class="ws">            </span>if rv is None:</pre>
# <pre class="line current"><span class="ws">                </span>rv = self.dispatch_request()</pre>
# <pre class="line after"><span class="ws">        </span>except Exception as e:</pre>
# <pre class="line after"><span class="ws">            </span>rv = self.handle_user_exception(e)</pre>
# <pre class="line after"><span class="ws">        </span>return self.finalize_request(rv)</pre>
# <pre class="line after"><span class="ws"></span> </pre>
# <pre class="line after"><span class="ws">    </span>def finalize_request(</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140249946327456">
#   <h4>File <cite class="filename">"/opt/app-root/lib/python3.8/site-packages/flask/app.py"</cite>,
#       line <em class="line">1502</em>,
#       in <code class="function">dispatch_request</code></h4>
#   <div class="source "><pre class="line before"><span class="ws">            </span>getattr(rule, &quot;provide_automatic_options&quot;, False)</pre>
# <pre class="line before"><span class="ws">            </span>and req.method == &quot;OPTIONS&quot;</pre>
# <pre class="line before"><span class="ws">        </span>):</pre>
# <pre class="line before"><span class="ws">            </span>return self.make_default_options_response()</pre>
# <pre class="line before"><span class="ws">        </span># otherwise dispatch to the handler for that endpoint</pre>
# <pre class="line current"><span class="ws">        </span>return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)</pre>
# <pre class="line after"><span class="ws"></span> </pre>
# <pre class="line after"><span class="ws">    </span>def full_dispatch_request(self) -&gt; Response:</pre>
# <pre class="line after"><span class="ws">        </span>&quot;&quot;&quot;Dispatches the request and on top of that performs request</pre>
# <pre class="line after"><span class="ws">        </span>pre and postprocessing as well as HTTP exception catching and</pre>
# <pre class="line after"><span class="ws">        </span>error handling.</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140249946327840">
#   <h4>File <cite class="filename">"/opt/app-root/src/Semantic-Image-Segmentation-Workshop/wsgi.py"</cite>,
#       line <em class="line">17</em>,
#       in <code class="function">object_detection</code></h4>
#   <div class="source "><pre class="line before"><span class="ws"></span> </pre>
# <pre class="line before"><span class="ws"></span>@application.route(&#x27;/predictions&#x27;, methods=[&#x27;POST&#x27;])</pre>
# <pre class="line before"><span class="ws"></span>def object_detection():</pre>
# <pre class="line before"><span class="ws">    </span>data = request.data or &#x27;{}&#x27;</pre>
# <pre class="line before"><span class="ws">    </span>body = json.loads(data)</pre>
# <pre class="line current"><span class="ws">    </span>return jsonify(predict(body))</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140249948889440">
#   <h4>File <cite class="filename">"/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py"</cite>,
#       line <em class="line">177</em>,
#       in <code class="function">predict</code></h4>
#   <div class="source "><pre class="line before"><span class="ws">        </span>pred_mask = process_base64_image(args_dict)</pre>
# <pre class="line before"><span class="ws">    </span>else:</pre>
# <pre class="line before"><span class="ws">        </span>filename = os.path.join(&#x27;dataset/images&#x27;, args_dict.get(&#x27;data&#x27;))</pre>
# <pre class="line before"><span class="ws">        </span>print(filename)</pre>
# <pre class="line before"><span class="ws">        </span>print(&quot;2&quot;)</pre>
# <pre class="line current"><span class="ws">        </span>pred_mask = process_file(filename)</pre>
# <pre class="line after"><span class="ws">    </span>return {&#x27;pred_mask&#x27;: pred_mask.numpy().tolist()}</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140249948890544">
#   <h4>File <cite class="filename">"/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py"</cite>,
#       line <em class="line">149</em>,
#       in <code class="function">process_file</code></h4>
#   <div class="source "><pre class="line before"><span class="ws"></span> </pre>
# <pre class="line before"><span class="ws"></span> </pre>
# <pre class="line before"><span class="ws"></span> </pre>
# <pre class="line before"><span class="ws"></span>def process_file(filename):</pre>
# <pre class="line before"><span class="ws">    </span>if filename.endswith(&quot;.jpg&quot;) or filename.endswith(&quot;.jpeg&quot;) or filename.endswith(&quot;.png&quot;):</pre>
# <pre class="line current"><span class="ws">        </span>pred_mask = get_segmentation(filename)</pre>
# <pre class="line after"><span class="ws">    </span>else:</pre>
# <pre class="line after"><span class="ws">        </span>pred_mask = &#x27;This is not a valid image file&#x27;</pre>
# <pre class="line after"><span class="ws">        </span>input_image = &#x27;none&#x27;</pre>
# <pre class="line after"><span class="ws">        </span>print(pred_mask)</pre>
# <pre class="line after"><span class="ws">    </span>return pred_mask</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140249946307216">
#   <h4>File <cite class="filename">"/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py"</cite>,
#       line <em class="line">139</em>,
#       in <code class="function">get_segmentation</code></h4>
#   <div class="source "><pre class="line before"><span class="ws"></span> </pre>
# <pre class="line before"><span class="ws"></span>##############################################################################</pre>
# <pre class="line before"><span class="ws"></span># Returns the image of the car (vehicle) and the Licence plate image (LpImg) #</pre>
# <pre class="line before"><span class="ws"></span>##############################################################################</pre>
# <pre class="line before"><span class="ws"></span>def get_segmentation(image_path, Dmax=608, Dmin = 608):</pre>
# <pre class="line current"><span class="ws">    </span>input_image = preprocess_image(image_path)</pre>
# <pre class="line after"><span class="ws">    </span>pred_mask = model(input_image)</pre>
# <pre class="line after"><span class="ws"></span> </pre>
# <pre class="line after"><span class="ws">    </span>show_predictions(input_image, pred_mask)</pre>
# <pre class="line after"><span class="ws">    </span>return create_mask(pred_mask)</pre>
# <pre class="line after"><span class="ws"></span> </pre></div>
# </div>
#
# <li><div class="frame" id="frame-140249948889584">
#   <h4>File <cite class="filename">"/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py"</cite>,
#       line <em class="line">74</em>,
#       in <code class="function">preprocess_image</code></h4>
#   <div class="source "><pre class="line before"><span class="ws"></span># Converts colors from BGR (as read by OpenCV) to RGB (so that we can display them), #</pre>
# <pre class="line before"><span class="ws"></span># also eventually resizes the image to fit the size the model has been trained on    #</pre>
# <pre class="line before"><span class="ws"></span>######################################################################################</pre>
# <pre class="line before"><span class="ws"></span>def preprocess_image(image_path,resize=True):</pre>
# <pre class="line before"><span class="ws">    </span>img = cv2.imread(image_path)</pre>
# <pre class="line current"><span class="ws">    </span>img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)</pre>
# <pre class="line after"><span class="ws">    </span># img = img / 1.0</pre>
# <pre class="line after"><span class="ws">    </span># img = img / 255</pre>
# <pre class="line after"><span class="ws">    </span>if resize:</pre>
# <pre class="line after"><span class="ws">        </span>img = cv2.resize(img, (128,128))</pre>
# <pre class="line after"><span class="ws">    </span>img = np.expand_dims(img, axis=0)</pre></div>
# </div>
# </ul>
#   <blockquote>cv2.error: OpenCV(4.5.5) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function &#x27;cvtColor&#x27;</blockquote>
# </div>
#
# <div class="plain">
#     <p>
#       This is the Copy/Paste friendly version of the traceback.
#     </p>
#     <textarea cols="50" rows="10" name="code" readonly>Traceback (most recent call last):
#   File &quot;/opt/app-root/lib/python3.8/site-packages/flask/app.py&quot;, line 2091, in __call__
#     return self.wsgi_app(environ, start_response)
#   File &quot;/opt/app-root/lib/python3.8/site-packages/flask/app.py&quot;, line 2076, in wsgi_app
#     response = self.handle_exception(e)
#   File &quot;/opt/app-root/lib/python3.8/site-packages/flask/app.py&quot;, line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File &quot;/opt/app-root/lib/python3.8/site-packages/flask/app.py&quot;, line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File &quot;/opt/app-root/lib/python3.8/site-packages/flask/app.py&quot;, line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File &quot;/opt/app-root/lib/python3.8/site-packages/flask/app.py&quot;, line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File &quot;/opt/app-root/src/Semantic-Image-Segmentation-Workshop/wsgi.py&quot;, line 17, in object_detection
#     return jsonify(predict(body))
#   File &quot;/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py&quot;, line 177, in predict
#     pred_mask = process_file(filename)
#   File &quot;/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py&quot;, line 149, in process_file
#     pred_mask = get_segmentation(filename)
#   File &quot;/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py&quot;, line 139, in get_segmentation
#     input_image = preprocess_image(image_path)
#   File &quot;/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py&quot;, line 74, in preprocess_image
#     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# cv2.error: OpenCV(4.5.5) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function &#x27;cvtColor&#x27;</textarea>
# </div>
# <div class="explanation">
#   The debugger caught an exception in your WSGI application.  You can now
#   look at the traceback which led to the error.  <span class="nojavascript">
#   If you enable JavaScript you can also use additional features such as code
#   execution (if the evalex feature is enabled), automatic pasting of the
#   exceptions and much more.</span>
# </div>
#       <div class="footer">
#         Brought to you by <strong class="arthur">DON'T PANIC</strong>, your
#         friendly Werkzeug powered traceback interpreter.
#       </div>
#     </div>
#
#     <div class="pin-prompt">
#       <div class="inner">
#         <h3>Console Locked</h3>
#         <p>
#           The console is locked and needs to be unlocked by entering the PIN.
#           You can find the PIN printed out on the standard output of your
#           shell that runs the server.
#         <form>
#           <p>PIN:
#             <input type=text name=pin size=14>
#             <input type=submit name=btn value="Confirm Pin">
#         </form>
#       </div>
#     </div>
#   </body>
# </html>
#
# <!--
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2091, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2076, in wsgi_app
#     response = self.handle_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "/opt/app-root/src/Semantic-Image-Segmentation-Workshop/wsgi.py", line 17, in object_detection
#     return jsonify(predict(body))
#   File "/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py", line 177, in predict
#     pred_mask = process_file(filename)
#   File "/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py", line 149, in process_file
#     pred_mask = get_segmentation(filename)
#   File "/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py", line 139, in get_segmentation
#     input_image = preprocess_image(image_path)
#   File "/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py", line 74, in preprocess_image
#     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# cv2.error: OpenCV(4.5.5) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# -->

# %% [markdown]
# We could also do it using pure Python code:

# %%
import requests
import json
response = requests.post('http://127.0.0.1:5000/predictions', '{"data": "test_sample_256_10.jpg"}')
response.json()['pred_mask']
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File /opt/app-root/lib64/python3.8/site-packages/requests/models.py:910, in Response.json(self, **kwargs)
#     909 try:
# --> 910     return complexjson.loads(self.text, **kwargs)
#     911 except JSONDecodeError as e:
#     912     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     913     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /usr/lib64/python3.8/json/__init__.py:357, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     354 if (cls is None and object_hook is None and
#     355         parse_int is None and parse_float is None and
#     356         parse_constant is None and object_pairs_hook is None and not kw):
# --> 357     return _default_decoder.decode(s)
#     358 if cls is None:
#
# File /usr/lib64/python3.8/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File /usr/lib64/python3.8/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Input In [7], in <module>
#       2 import json
#       3 response = requests.post('http://127.0.0.1:5000/predictions', '{"data": "test_sample_256_10.jpg"}')
# ----> 4 response.json()['pred_mask']
#
# File /opt/app-root/lib64/python3.8/site-packages/requests/models.py:917, in Response.json(self, **kwargs)
#     915     raise RequestsJSONDecodeError(e.message)
#     916 else:
# --> 917     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: [Errno Expecting value] <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN"
#   "http://www.w3.org/TR/html4/loose.dtd">
# <html>
#   <head>
#     <title>cv2.error: OpenCV(4.5.5) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function &#x27;cvtColor&#x27; // Werkzeug Debugger</title>
#     <link rel="stylesheet" href="?__debugger__=yes&amp;cmd=resource&amp;f=style.css"
#         type="text/css">
#     <!-- We need to make sure this has a favicon so that the debugger does
#          not accidentally trigger a request to /favicon.ico which might
#          change the application's state. -->
#     <link rel="shortcut icon"
#         href="?__debugger__=yes&amp;cmd=resource&amp;f=console.png">
#     <script src="?__debugger__=yes&amp;cmd=resource&amp;f=debugger.js"></script>
#     <script type="text/javascript">
#       var TRACEBACK = 140409663565056,
#           CONSOLE_MODE = false,
#           EVALEX = true,
#           EVALEX_TRUSTED = false,
#           SECRET = "UdgPh0F20sNPprvARX7i";
#     </script>
#   </head>
#   <body style="background-color: #fff">
#     <div class="debugger">
# <h1>cv2.error</h1>
# <div class="detail">
#   <p class="errormsg">cv2.error: OpenCV(4.5.5) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function &#x27;cvtColor&#x27;</p>
# </div>
# <h2 class="traceback">Traceback <em>(most recent call last)</em></h2>
# <div class="traceback">
#   <h3></h3>
#   <ul><li><div class="frame" id="frame-140409663291936">
#   <h4>File <cite class="filename">"/opt/app-root/lib/python3.8/site-packages/flask/app.py"</cite>,
#       line <em class="line">2091</em>,
#       in <code class="function">__call__</code></h4>
#   <div class="source "><pre class="line before"><span class="ws">    </span>def __call__(self, environ: dict, start_response: t.Callable) -&gt; t.Any:</pre>
# <pre class="line before"><span class="ws">        </span>&quot;&quot;&quot;The WSGI server calls the Flask application object as the</pre>
# <pre class="line before"><span class="ws">        </span>WSGI application. This calls :meth:`wsgi_app`, which can be</pre>
# <pre class="line before"><span class="ws">        </span>wrapped to apply middleware.</pre>
# <pre class="line before"><span class="ws">        </span>&quot;&quot;&quot;</pre>
# <pre class="line current"><span class="ws">        </span>return self.wsgi_app(environ, start_response)</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140409662265280">
#   <h4>File <cite class="filename">"/opt/app-root/lib/python3.8/site-packages/flask/app.py"</cite>,
#       line <em class="line">2076</em>,
#       in <code class="function">wsgi_app</code></h4>
#   <div class="source "><pre class="line before"><span class="ws">            </span>try:</pre>
# <pre class="line before"><span class="ws">                </span>ctx.push()</pre>
# <pre class="line before"><span class="ws">                </span>response = self.full_dispatch_request()</pre>
# <pre class="line before"><span class="ws">            </span>except Exception as e:</pre>
# <pre class="line before"><span class="ws">                </span>error = e</pre>
# <pre class="line current"><span class="ws">                </span>response = self.handle_exception(e)</pre>
# <pre class="line after"><span class="ws">            </span>except:  # noqa: B001</pre>
# <pre class="line after"><span class="ws">                </span>error = sys.exc_info()[1]</pre>
# <pre class="line after"><span class="ws">                </span>raise</pre>
# <pre class="line after"><span class="ws">            </span>return response(environ, start_response)</pre>
# <pre class="line after"><span class="ws">        </span>finally:</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140409662265232">
#   <h4>File <cite class="filename">"/opt/app-root/lib/python3.8/site-packages/flask/app.py"</cite>,
#       line <em class="line">2073</em>,
#       in <code class="function">wsgi_app</code></h4>
#   <div class="source "><pre class="line before"><span class="ws">        </span>ctx = self.request_context(environ)</pre>
# <pre class="line before"><span class="ws">        </span>error: t.Optional[BaseException] = None</pre>
# <pre class="line before"><span class="ws">        </span>try:</pre>
# <pre class="line before"><span class="ws">            </span>try:</pre>
# <pre class="line before"><span class="ws">                </span>ctx.push()</pre>
# <pre class="line current"><span class="ws">                </span>response = self.full_dispatch_request()</pre>
# <pre class="line after"><span class="ws">            </span>except Exception as e:</pre>
# <pre class="line after"><span class="ws">                </span>error = e</pre>
# <pre class="line after"><span class="ws">                </span>response = self.handle_exception(e)</pre>
# <pre class="line after"><span class="ws">            </span>except:  # noqa: B001</pre>
# <pre class="line after"><span class="ws">                </span>error = sys.exc_info()[1]</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140409663321040">
#   <h4>File <cite class="filename">"/opt/app-root/lib/python3.8/site-packages/flask/app.py"</cite>,
#       line <em class="line">1518</em>,
#       in <code class="function">full_dispatch_request</code></h4>
#   <div class="source "><pre class="line before"><span class="ws">            </span>request_started.send(self)</pre>
# <pre class="line before"><span class="ws">            </span>rv = self.preprocess_request()</pre>
# <pre class="line before"><span class="ws">            </span>if rv is None:</pre>
# <pre class="line before"><span class="ws">                </span>rv = self.dispatch_request()</pre>
# <pre class="line before"><span class="ws">        </span>except Exception as e:</pre>
# <pre class="line current"><span class="ws">            </span>rv = self.handle_user_exception(e)</pre>
# <pre class="line after"><span class="ws">        </span>return self.finalize_request(rv)</pre>
# <pre class="line after"><span class="ws"></span> </pre>
# <pre class="line after"><span class="ws">    </span>def finalize_request(</pre>
# <pre class="line after"><span class="ws">        </span>self,</pre>
# <pre class="line after"><span class="ws">        </span>rv: t.Union[ResponseReturnValue, HTTPException],</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140409663321328">
#   <h4>File <cite class="filename">"/opt/app-root/lib/python3.8/site-packages/flask/app.py"</cite>,
#       line <em class="line">1516</em>,
#       in <code class="function">full_dispatch_request</code></h4>
#   <div class="source "><pre class="line before"><span class="ws">        </span>self.try_trigger_before_first_request_functions()</pre>
# <pre class="line before"><span class="ws">        </span>try:</pre>
# <pre class="line before"><span class="ws">            </span>request_started.send(self)</pre>
# <pre class="line before"><span class="ws">            </span>rv = self.preprocess_request()</pre>
# <pre class="line before"><span class="ws">            </span>if rv is None:</pre>
# <pre class="line current"><span class="ws">                </span>rv = self.dispatch_request()</pre>
# <pre class="line after"><span class="ws">        </span>except Exception as e:</pre>
# <pre class="line after"><span class="ws">            </span>rv = self.handle_user_exception(e)</pre>
# <pre class="line after"><span class="ws">        </span>return self.finalize_request(rv)</pre>
# <pre class="line after"><span class="ws"></span> </pre>
# <pre class="line after"><span class="ws">    </span>def finalize_request(</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140409663323680">
#   <h4>File <cite class="filename">"/opt/app-root/lib/python3.8/site-packages/flask/app.py"</cite>,
#       line <em class="line">1502</em>,
#       in <code class="function">dispatch_request</code></h4>
#   <div class="source "><pre class="line before"><span class="ws">            </span>getattr(rule, &quot;provide_automatic_options&quot;, False)</pre>
# <pre class="line before"><span class="ws">            </span>and req.method == &quot;OPTIONS&quot;</pre>
# <pre class="line before"><span class="ws">        </span>):</pre>
# <pre class="line before"><span class="ws">            </span>return self.make_default_options_response()</pre>
# <pre class="line before"><span class="ws">        </span># otherwise dispatch to the handler for that endpoint</pre>
# <pre class="line current"><span class="ws">        </span>return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)</pre>
# <pre class="line after"><span class="ws"></span> </pre>
# <pre class="line after"><span class="ws">    </span>def full_dispatch_request(self) -&gt; Response:</pre>
# <pre class="line after"><span class="ws">        </span>&quot;&quot;&quot;Dispatches the request and on top of that performs request</pre>
# <pre class="line after"><span class="ws">        </span>pre and postprocessing as well as HTTP exception catching and</pre>
# <pre class="line after"><span class="ws">        </span>error handling.</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140409663639072">
#   <h4>File <cite class="filename">"/opt/app-root/src/Semantic-Image-Segmentation-Workshop/wsgi.py"</cite>,
#       line <em class="line">17</em>,
#       in <code class="function">object_detection</code></h4>
#   <div class="source "><pre class="line before"><span class="ws"></span> </pre>
# <pre class="line before"><span class="ws"></span>@application.route(&#x27;/predictions&#x27;, methods=[&#x27;POST&#x27;])</pre>
# <pre class="line before"><span class="ws"></span>def object_detection():</pre>
# <pre class="line before"><span class="ws">    </span>data = request.data or &#x27;{}&#x27;</pre>
# <pre class="line before"><span class="ws">    </span>body = json.loads(data)</pre>
# <pre class="line current"><span class="ws">    </span>return jsonify(predict(body))</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140409663639168">
#   <h4>File <cite class="filename">"/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py"</cite>,
#       line <em class="line">178</em>,
#       in <code class="function">predict</code></h4>
#   <div class="source "><pre class="line before"><span class="ws">        </span>pred_mask = process_base64_image(args_dict)</pre>
# <pre class="line before"><span class="ws">    </span>else:</pre>
# <pre class="line before"><span class="ws">        </span>filename = os.path.join(&#x27;dataset/images&#x27;, args_dict.get(&#x27;data&#x27;))</pre>
# <pre class="line before"><span class="ws">        </span>print(filename)</pre>
# <pre class="line before"><span class="ws">        </span>print(&quot;2&quot;)</pre>
# <pre class="line current"><span class="ws">        </span>pred_mask = process_file(filename)</pre>
# <pre class="line after"><span class="ws">    </span>return {&#x27;pred_mask&#x27;: pred_mask.numpy().tolist()}</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140409664066800">
#   <h4>File <cite class="filename">"/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py"</cite>,
#       line <em class="line">150</em>,
#       in <code class="function">process_file</code></h4>
#   <div class="source "><pre class="line before"><span class="ws"></span> </pre>
# <pre class="line before"><span class="ws"></span> </pre>
# <pre class="line before"><span class="ws"></span> </pre>
# <pre class="line before"><span class="ws"></span>def process_file(filename):</pre>
# <pre class="line before"><span class="ws">    </span>if filename.endswith(&quot;.jpg&quot;) or filename.endswith(&quot;.jpeg&quot;) or filename.endswith(&quot;.png&quot;):</pre>
# <pre class="line current"><span class="ws">        </span>pred_mask = get_segmentation(filename)</pre>
# <pre class="line after"><span class="ws">    </span>else:</pre>
# <pre class="line after"><span class="ws">        </span>pred_mask = &#x27;This is not a valid image file&#x27;</pre>
# <pre class="line after"><span class="ws">        </span>input_image = &#x27;none&#x27;</pre>
# <pre class="line after"><span class="ws">        </span>print(pred_mask)</pre>
# <pre class="line after"><span class="ws">    </span>return pred_mask</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140409662058896">
#   <h4>File <cite class="filename">"/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py"</cite>,
#       line <em class="line">140</em>,
#       in <code class="function">get_segmentation</code></h4>
#   <div class="source "><pre class="line before"><span class="ws"></span> </pre>
# <pre class="line before"><span class="ws"></span>##############################################################################</pre>
# <pre class="line before"><span class="ws"></span># Returns the image of the car (vehicle) and the Licence plate image (LpImg) #</pre>
# <pre class="line before"><span class="ws"></span>##############################################################################</pre>
# <pre class="line before"><span class="ws"></span>def get_segmentation(image_path, Dmax=608, Dmin = 608):</pre>
# <pre class="line current"><span class="ws">    </span>input_image = preprocess_image(image_path)</pre>
# <pre class="line after"><span class="ws">    </span>pred_mask = model(input_image)</pre>
# <pre class="line after"><span class="ws"></span> </pre>
# <pre class="line after"><span class="ws">    </span>show_predictions(input_image, pred_mask)</pre>
# <pre class="line after"><span class="ws">    </span>return create_mask(pred_mask)</pre>
# <pre class="line after"><span class="ws"></span> </pre></div>
# </div>
#
# <li><div class="frame" id="frame-140409664067088">
#   <h4>File <cite class="filename">"/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py"</cite>,
#       line <em class="line">75</em>,
#       in <code class="function">preprocess_image</code></h4>
#   <div class="source "><pre class="line before"><span class="ws"></span># also eventually resizes the image to fit the size the model has been trained on    #</pre>
# <pre class="line before"><span class="ws"></span>######################################################################################</pre>
# <pre class="line before"><span class="ws"></span>def preprocess_image(image_path,resize=True):</pre>
# <pre class="line before"><span class="ws">    </span>img = cv2.imread(image_path)</pre>
# <pre class="line before"><span class="ws">    </span>print(img)</pre>
# <pre class="line current"><span class="ws">    </span>img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)</pre>
# <pre class="line after"><span class="ws">    </span># img = img / 1.0</pre>
# <pre class="line after"><span class="ws">    </span># img = img / 255</pre>
# <pre class="line after"><span class="ws">    </span>if resize:</pre>
# <pre class="line after"><span class="ws">        </span>img = cv2.resize(img, (128,128))</pre>
# <pre class="line after"><span class="ws">    </span>img = np.expand_dims(img, axis=0)</pre></div>
# </div>
# </ul>
#   <blockquote>cv2.error: OpenCV(4.5.5) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function &#x27;cvtColor&#x27;</blockquote>
# </div>
#
# <div class="plain">
#     <p>
#       This is the Copy/Paste friendly version of the traceback.
#     </p>
#     <textarea cols="50" rows="10" name="code" readonly>Traceback (most recent call last):
#   File &quot;/opt/app-root/lib/python3.8/site-packages/flask/app.py&quot;, line 2091, in __call__
#     return self.wsgi_app(environ, start_response)
#   File &quot;/opt/app-root/lib/python3.8/site-packages/flask/app.py&quot;, line 2076, in wsgi_app
#     response = self.handle_exception(e)
#   File &quot;/opt/app-root/lib/python3.8/site-packages/flask/app.py&quot;, line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File &quot;/opt/app-root/lib/python3.8/site-packages/flask/app.py&quot;, line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File &quot;/opt/app-root/lib/python3.8/site-packages/flask/app.py&quot;, line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File &quot;/opt/app-root/lib/python3.8/site-packages/flask/app.py&quot;, line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File &quot;/opt/app-root/src/Semantic-Image-Segmentation-Workshop/wsgi.py&quot;, line 17, in object_detection
#     return jsonify(predict(body))
#   File &quot;/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py&quot;, line 178, in predict
#     pred_mask = process_file(filename)
#   File &quot;/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py&quot;, line 150, in process_file
#     pred_mask = get_segmentation(filename)
#   File &quot;/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py&quot;, line 140, in get_segmentation
#     input_image = preprocess_image(image_path)
#   File &quot;/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py&quot;, line 75, in preprocess_image
#     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# cv2.error: OpenCV(4.5.5) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function &#x27;cvtColor&#x27;</textarea>
# </div>
# <div class="explanation">
#   The debugger caught an exception in your WSGI application.  You can now
#   look at the traceback which led to the error.  <span class="nojavascript">
#   If you enable JavaScript you can also use additional features such as code
#   execution (if the evalex feature is enabled), automatic pasting of the
#   exceptions and much more.</span>
# </div>
#       <div class="footer">
#         Brought to you by <strong class="arthur">DON'T PANIC</strong>, your
#         friendly Werkzeug powered traceback interpreter.
#       </div>
#     </div>
#
#     <div class="pin-prompt">
#       <div class="inner">
#         <h3>Console Locked</h3>
#         <p>
#           The console is locked and needs to be unlocked by entering the PIN.
#           You can find the PIN printed out on the standard output of your
#           shell that runs the server.
#         <form>
#           <p>PIN:
#             <input type=text name=pin size=14>
#             <input type=submit name=btn value="Confirm Pin">
#         </form>
#       </div>
#     </div>
#   </body>
# </html>
#
# <!--
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2091, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2076, in wsgi_app
#     response = self.handle_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "/opt/app-root/src/Semantic-Image-Segmentation-Workshop/wsgi.py", line 17, in object_detection
#     return jsonify(predict(body))
#   File "/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py", line 178, in predict
#     pred_mask = process_file(filename)
#   File "/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py", line 150, in process_file
#     pred_mask = get_segmentation(filename)
#   File "/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py", line 140, in get_segmentation
#     input_image = preprocess_image(image_path)
#   File "/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py", line 75, in preprocess_image
#     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# cv2.error: OpenCV(4.5.5) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# -->
# : 0

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.imshow(np.array(response.json()['pred_mask']))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File /opt/app-root/lib64/python3.8/site-packages/requests/models.py:910, in Response.json(self, **kwargs)
#     909 try:
# --> 910     return complexjson.loads(self.text, **kwargs)
#     911 except JSONDecodeError as e:
#     912     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     913     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /usr/lib64/python3.8/json/__init__.py:357, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     354 if (cls is None and object_hook is None and
#     355         parse_int is None and parse_float is None and
#     356         parse_constant is None and object_pairs_hook is None and not kw):
# --> 357     return _default_decoder.decode(s)
#     358 if cls is None:
#
# File /usr/lib64/python3.8/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File /usr/lib64/python3.8/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Input In [6], in <module>
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 3 plt.imshow(np.array(response.json()['pred_mask']))
#
# File /opt/app-root/lib64/python3.8/site-packages/requests/models.py:917, in Response.json(self, **kwargs)
#     915     raise RequestsJSONDecodeError(e.message)
#     916 else:
# --> 917     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: [Errno Expecting value] <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN"
#   "http://www.w3.org/TR/html4/loose.dtd">
# <html>
#   <head>
#     <title>cv2.error: OpenCV(4.5.5) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function &#x27;cvtColor&#x27; // Werkzeug Debugger</title>
#     <link rel="stylesheet" href="?__debugger__=yes&amp;cmd=resource&amp;f=style.css"
#         type="text/css">
#     <!-- We need to make sure this has a favicon so that the debugger does
#          not accidentally trigger a request to /favicon.ico which might
#          change the application's state. -->
#     <link rel="shortcut icon"
#         href="?__debugger__=yes&amp;cmd=resource&amp;f=console.png">
#     <script src="?__debugger__=yes&amp;cmd=resource&amp;f=debugger.js"></script>
#     <script type="text/javascript">
#       var TRACEBACK = 140409663674832,
#           CONSOLE_MODE = false,
#           EVALEX = true,
#           EVALEX_TRUSTED = false,
#           SECRET = "UdgPh0F20sNPprvARX7i";
#     </script>
#   </head>
#   <body style="background-color: #fff">
#     <div class="debugger">
# <h1>cv2.error</h1>
# <div class="detail">
#   <p class="errormsg">cv2.error: OpenCV(4.5.5) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function &#x27;cvtColor&#x27;</p>
# </div>
# <h2 class="traceback">Traceback <em>(most recent call last)</em></h2>
# <div class="traceback">
#   <h3></h3>
#   <ul><li><div class="frame" id="frame-140409689940896">
#   <h4>File <cite class="filename">"/opt/app-root/lib/python3.8/site-packages/flask/app.py"</cite>,
#       line <em class="line">2091</em>,
#       in <code class="function">__call__</code></h4>
#   <div class="source "><pre class="line before"><span class="ws">    </span>def __call__(self, environ: dict, start_response: t.Callable) -&gt; t.Any:</pre>
# <pre class="line before"><span class="ws">        </span>&quot;&quot;&quot;The WSGI server calls the Flask application object as the</pre>
# <pre class="line before"><span class="ws">        </span>WSGI application. This calls :meth:`wsgi_app`, which can be</pre>
# <pre class="line before"><span class="ws">        </span>wrapped to apply middleware.</pre>
# <pre class="line before"><span class="ws">        </span>&quot;&quot;&quot;</pre>
# <pre class="line current"><span class="ws">        </span>return self.wsgi_app(environ, start_response)</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140409397033424">
#   <h4>File <cite class="filename">"/opt/app-root/lib/python3.8/site-packages/flask/app.py"</cite>,
#       line <em class="line">2076</em>,
#       in <code class="function">wsgi_app</code></h4>
#   <div class="source "><pre class="line before"><span class="ws">            </span>try:</pre>
# <pre class="line before"><span class="ws">                </span>ctx.push()</pre>
# <pre class="line before"><span class="ws">                </span>response = self.full_dispatch_request()</pre>
# <pre class="line before"><span class="ws">            </span>except Exception as e:</pre>
# <pre class="line before"><span class="ws">                </span>error = e</pre>
# <pre class="line current"><span class="ws">                </span>response = self.handle_exception(e)</pre>
# <pre class="line after"><span class="ws">            </span>except:  # noqa: B001</pre>
# <pre class="line after"><span class="ws">                </span>error = sys.exc_info()[1]</pre>
# <pre class="line after"><span class="ws">                </span>raise</pre>
# <pre class="line after"><span class="ws">            </span>return response(environ, start_response)</pre>
# <pre class="line after"><span class="ws">        </span>finally:</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140409662540384">
#   <h4>File <cite class="filename">"/opt/app-root/lib/python3.8/site-packages/flask/app.py"</cite>,
#       line <em class="line">2073</em>,
#       in <code class="function">wsgi_app</code></h4>
#   <div class="source "><pre class="line before"><span class="ws">        </span>ctx = self.request_context(environ)</pre>
# <pre class="line before"><span class="ws">        </span>error: t.Optional[BaseException] = None</pre>
# <pre class="line before"><span class="ws">        </span>try:</pre>
# <pre class="line before"><span class="ws">            </span>try:</pre>
# <pre class="line before"><span class="ws">                </span>ctx.push()</pre>
# <pre class="line current"><span class="ws">                </span>response = self.full_dispatch_request()</pre>
# <pre class="line after"><span class="ws">            </span>except Exception as e:</pre>
# <pre class="line after"><span class="ws">                </span>error = e</pre>
# <pre class="line after"><span class="ws">                </span>response = self.handle_exception(e)</pre>
# <pre class="line after"><span class="ws">            </span>except:  # noqa: B001</pre>
# <pre class="line after"><span class="ws">                </span>error = sys.exc_info()[1]</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140409397034720">
#   <h4>File <cite class="filename">"/opt/app-root/lib/python3.8/site-packages/flask/app.py"</cite>,
#       line <em class="line">1518</em>,
#       in <code class="function">full_dispatch_request</code></h4>
#   <div class="source "><pre class="line before"><span class="ws">            </span>request_started.send(self)</pre>
# <pre class="line before"><span class="ws">            </span>rv = self.preprocess_request()</pre>
# <pre class="line before"><span class="ws">            </span>if rv is None:</pre>
# <pre class="line before"><span class="ws">                </span>rv = self.dispatch_request()</pre>
# <pre class="line before"><span class="ws">        </span>except Exception as e:</pre>
# <pre class="line current"><span class="ws">            </span>rv = self.handle_user_exception(e)</pre>
# <pre class="line after"><span class="ws">        </span>return self.finalize_request(rv)</pre>
# <pre class="line after"><span class="ws"></span> </pre>
# <pre class="line after"><span class="ws">    </span>def finalize_request(</pre>
# <pre class="line after"><span class="ws">        </span>self,</pre>
# <pre class="line after"><span class="ws">        </span>rv: t.Union[ResponseReturnValue, HTTPException],</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140409401047264">
#   <h4>File <cite class="filename">"/opt/app-root/lib/python3.8/site-packages/flask/app.py"</cite>,
#       line <em class="line">1516</em>,
#       in <code class="function">full_dispatch_request</code></h4>
#   <div class="source "><pre class="line before"><span class="ws">        </span>self.try_trigger_before_first_request_functions()</pre>
# <pre class="line before"><span class="ws">        </span>try:</pre>
# <pre class="line before"><span class="ws">            </span>request_started.send(self)</pre>
# <pre class="line before"><span class="ws">            </span>rv = self.preprocess_request()</pre>
# <pre class="line before"><span class="ws">            </span>if rv is None:</pre>
# <pre class="line current"><span class="ws">                </span>rv = self.dispatch_request()</pre>
# <pre class="line after"><span class="ws">        </span>except Exception as e:</pre>
# <pre class="line after"><span class="ws">            </span>rv = self.handle_user_exception(e)</pre>
# <pre class="line after"><span class="ws">        </span>return self.finalize_request(rv)</pre>
# <pre class="line after"><span class="ws"></span> </pre>
# <pre class="line after"><span class="ws">    </span>def finalize_request(</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140409401047360">
#   <h4>File <cite class="filename">"/opt/app-root/lib/python3.8/site-packages/flask/app.py"</cite>,
#       line <em class="line">1502</em>,
#       in <code class="function">dispatch_request</code></h4>
#   <div class="source "><pre class="line before"><span class="ws">            </span>getattr(rule, &quot;provide_automatic_options&quot;, False)</pre>
# <pre class="line before"><span class="ws">            </span>and req.method == &quot;OPTIONS&quot;</pre>
# <pre class="line before"><span class="ws">        </span>):</pre>
# <pre class="line before"><span class="ws">            </span>return self.make_default_options_response()</pre>
# <pre class="line before"><span class="ws">        </span># otherwise dispatch to the handler for that endpoint</pre>
# <pre class="line current"><span class="ws">        </span>return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)</pre>
# <pre class="line after"><span class="ws"></span> </pre>
# <pre class="line after"><span class="ws">    </span>def full_dispatch_request(self) -&gt; Response:</pre>
# <pre class="line after"><span class="ws">        </span>&quot;&quot;&quot;Dispatches the request and on top of that performs request</pre>
# <pre class="line after"><span class="ws">        </span>pre and postprocessing as well as HTTP exception catching and</pre>
# <pre class="line after"><span class="ws">        </span>error handling.</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140409662617872">
#   <h4>File <cite class="filename">"/opt/app-root/src/Semantic-Image-Segmentation-Workshop/wsgi.py"</cite>,
#       line <em class="line">17</em>,
#       in <code class="function">object_detection</code></h4>
#   <div class="source "><pre class="line before"><span class="ws"></span> </pre>
# <pre class="line before"><span class="ws"></span>@application.route(&#x27;/predictions&#x27;, methods=[&#x27;POST&#x27;])</pre>
# <pre class="line before"><span class="ws"></span>def object_detection():</pre>
# <pre class="line before"><span class="ws">    </span>data = request.data or &#x27;{}&#x27;</pre>
# <pre class="line before"><span class="ws">    </span>body = json.loads(data)</pre>
# <pre class="line current"><span class="ws">    </span>return jsonify(predict(body))</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140409662617920">
#   <h4>File <cite class="filename">"/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py"</cite>,
#       line <em class="line">178</em>,
#       in <code class="function">predict</code></h4>
#   <div class="source "><pre class="line before"><span class="ws">        </span>pred_mask = process_base64_image(args_dict)</pre>
# <pre class="line before"><span class="ws">    </span>else:</pre>
# <pre class="line before"><span class="ws">        </span>filename = os.path.join(&#x27;dataset/images&#x27;, args_dict.get(&#x27;data&#x27;))</pre>
# <pre class="line before"><span class="ws">        </span>print(filename)</pre>
# <pre class="line before"><span class="ws">        </span>print(&quot;2&quot;)</pre>
# <pre class="line current"><span class="ws">        </span>pred_mask = process_file(filename)</pre>
# <pre class="line after"><span class="ws">    </span>return {&#x27;pred_mask&#x27;: pred_mask.numpy().tolist()}</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140409662802864">
#   <h4>File <cite class="filename">"/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py"</cite>,
#       line <em class="line">150</em>,
#       in <code class="function">process_file</code></h4>
#   <div class="source "><pre class="line before"><span class="ws"></span> </pre>
# <pre class="line before"><span class="ws"></span> </pre>
# <pre class="line before"><span class="ws"></span> </pre>
# <pre class="line before"><span class="ws"></span>def process_file(filename):</pre>
# <pre class="line before"><span class="ws">    </span>if filename.endswith(&quot;.jpg&quot;) or filename.endswith(&quot;.jpeg&quot;) or filename.endswith(&quot;.png&quot;):</pre>
# <pre class="line current"><span class="ws">        </span>pred_mask = get_segmentation(filename)</pre>
# <pre class="line after"><span class="ws">    </span>else:</pre>
# <pre class="line after"><span class="ws">        </span>pred_mask = &#x27;This is not a valid image file&#x27;</pre>
# <pre class="line after"><span class="ws">        </span>input_image = &#x27;none&#x27;</pre>
# <pre class="line after"><span class="ws">        </span>print(pred_mask)</pre>
# <pre class="line after"><span class="ws">    </span>return pred_mask</pre></div>
# </div>
#
# <li><div class="frame" id="frame-140409662802816">
#   <h4>File <cite class="filename">"/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py"</cite>,
#       line <em class="line">140</em>,
#       in <code class="function">get_segmentation</code></h4>
#   <div class="source "><pre class="line before"><span class="ws"></span> </pre>
# <pre class="line before"><span class="ws"></span>##############################################################################</pre>
# <pre class="line before"><span class="ws"></span># Returns the image of the car (vehicle) and the Licence plate image (LpImg) #</pre>
# <pre class="line before"><span class="ws"></span>##############################################################################</pre>
# <pre class="line before"><span class="ws"></span>def get_segmentation(image_path, Dmax=608, Dmin = 608):</pre>
# <pre class="line current"><span class="ws">    </span>input_image = preprocess_image(image_path)</pre>
# <pre class="line after"><span class="ws">    </span>pred_mask = model(input_image)</pre>
# <pre class="line after"><span class="ws"></span> </pre>
# <pre class="line after"><span class="ws">    </span>show_predictions(input_image, pred_mask)</pre>
# <pre class="line after"><span class="ws">    </span>return create_mask(pred_mask)</pre>
# <pre class="line after"><span class="ws"></span> </pre></div>
# </div>
#
# <li><div class="frame" id="frame-140409397031600">
#   <h4>File <cite class="filename">"/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py"</cite>,
#       line <em class="line">75</em>,
#       in <code class="function">preprocess_image</code></h4>
#   <div class="source "><pre class="line before"><span class="ws"></span># also eventually resizes the image to fit the size the model has been trained on    #</pre>
# <pre class="line before"><span class="ws"></span>######################################################################################</pre>
# <pre class="line before"><span class="ws"></span>def preprocess_image(image_path,resize=True):</pre>
# <pre class="line before"><span class="ws">    </span>img = cv2.imread(image_path)</pre>
# <pre class="line before"><span class="ws">    </span>print(img)</pre>
# <pre class="line current"><span class="ws">    </span>img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)</pre>
# <pre class="line after"><span class="ws">    </span># img = img / 1.0</pre>
# <pre class="line after"><span class="ws">    </span># img = img / 255</pre>
# <pre class="line after"><span class="ws">    </span>if resize:</pre>
# <pre class="line after"><span class="ws">        </span>img = cv2.resize(img, (128,128))</pre>
# <pre class="line after"><span class="ws">    </span>img = np.expand_dims(img, axis=0)</pre></div>
# </div>
# </ul>
#   <blockquote>cv2.error: OpenCV(4.5.5) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function &#x27;cvtColor&#x27;</blockquote>
# </div>
#
# <div class="plain">
#     <p>
#       This is the Copy/Paste friendly version of the traceback.
#     </p>
#     <textarea cols="50" rows="10" name="code" readonly>Traceback (most recent call last):
#   File &quot;/opt/app-root/lib/python3.8/site-packages/flask/app.py&quot;, line 2091, in __call__
#     return self.wsgi_app(environ, start_response)
#   File &quot;/opt/app-root/lib/python3.8/site-packages/flask/app.py&quot;, line 2076, in wsgi_app
#     response = self.handle_exception(e)
#   File &quot;/opt/app-root/lib/python3.8/site-packages/flask/app.py&quot;, line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File &quot;/opt/app-root/lib/python3.8/site-packages/flask/app.py&quot;, line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File &quot;/opt/app-root/lib/python3.8/site-packages/flask/app.py&quot;, line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File &quot;/opt/app-root/lib/python3.8/site-packages/flask/app.py&quot;, line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File &quot;/opt/app-root/src/Semantic-Image-Segmentation-Workshop/wsgi.py&quot;, line 17, in object_detection
#     return jsonify(predict(body))
#   File &quot;/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py&quot;, line 178, in predict
#     pred_mask = process_file(filename)
#   File &quot;/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py&quot;, line 150, in process_file
#     pred_mask = get_segmentation(filename)
#   File &quot;/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py&quot;, line 140, in get_segmentation
#     input_image = preprocess_image(image_path)
#   File &quot;/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py&quot;, line 75, in preprocess_image
#     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# cv2.error: OpenCV(4.5.5) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function &#x27;cvtColor&#x27;</textarea>
# </div>
# <div class="explanation">
#   The debugger caught an exception in your WSGI application.  You can now
#   look at the traceback which led to the error.  <span class="nojavascript">
#   If you enable JavaScript you can also use additional features such as code
#   execution (if the evalex feature is enabled), automatic pasting of the
#   exceptions and much more.</span>
# </div>
#       <div class="footer">
#         Brought to you by <strong class="arthur">DON'T PANIC</strong>, your
#         friendly Werkzeug powered traceback interpreter.
#       </div>
#     </div>
#
#     <div class="pin-prompt">
#       <div class="inner">
#         <h3>Console Locked</h3>
#         <p>
#           The console is locked and needs to be unlocked by entering the PIN.
#           You can find the PIN printed out on the standard output of your
#           shell that runs the server.
#         <form>
#           <p>PIN:
#             <input type=text name=pin size=14>
#             <input type=submit name=btn value="Confirm Pin">
#         </form>
#       </div>
#     </div>
#   </body>
# </html>
#
# <!--
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2091, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2076, in wsgi_app
#     response = self.handle_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "/opt/app-root/src/Semantic-Image-Segmentation-Workshop/wsgi.py", line 17, in object_detection
#     return jsonify(predict(body))
#   File "/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py", line 178, in predict
#     pred_mask = process_file(filename)
#   File "/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py", line 150, in process_file
#     pred_mask = get_segmentation(filename)
#   File "/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py", line 140, in get_segmentation
#     input_image = preprocess_image(image_path)
#   File "/opt/app-root/src/Semantic-Image-Segmentation-Workshop/prediction.py", line 75, in preprocess_image
#     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# cv2.error: OpenCV(4.5.5) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# -->
# : 0

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# You can experiment with other images that you will find inside the dataset/images folder.
# If you want, you can even upload your own images in this folder and make some experiments!
#
# When you're finished, you can go back to the instuctions for the conclusion of this workshop.
